# %%
import pandas as pd
import os

# %% [markdown]
# ### Prepare data for analysis
#
# **site_visit_url:** websited the bot has visited
#
# **visit_id:** it says if the visit to the website is the same
#
# **crawl:** This data base only has non - disinformation websites (pilot_1_US_base) and disinformation websites (pilot_1_US_misinfo)
#
# **is_third_party:** cookie set by the domain visited (first-party) set by another domain = third_party (third-party)
#
# **disconnect_tracker_category:** if the third-party is associated with some type of content/function (Advertisement, Social,Fingerprinting...) that information is in this column. If none NaN
#
# **companies:** Big company behind the third-party

# %%
path = os.getcwd() 
data_path = path + "/companies_cookie_data_copy.csv"
df = pd.read_csv(data_path, sep=";")
df
# Out:
#        Unnamed: 0                                     site_visit_url  \
# 0               0                              http://www.bavnews.am
# 1               1                              http://www.bavnews.am
# 2               2                              http://www.bavnews.am
# 3               3                              http://www.bavnews.am
# 4               4                              http://www.bavnews.am
# ...           ...                                                ...
# 58897       58897  http://geoclub.info/instrumenty-gosdepa-g7-kop...
# 58898       58898  http://geoclub.info/instrumenty-gosdepa-g7-kop...
# 58899       58899  http://geoclub.info/instrumenty-gosdepa-g7-kop...
# 58900       58900  http://geoclub.info/instrumenty-gosdepa-g7-kop...
# 58901       58901  http://geoclub.info/instrumenty-gosdepa-g7-kop...
#
#                 visited_at     id  browser_id          visit_id  \
# 0      2021-09-08 15:14:09      3  2077116639  1976832558889756
# 1      2021-09-08 15:14:09      4  2077116639  1976832558889756
# 2      2021-09-08 15:14:09      7  2077116639  1976832558889756
# 3      2021-09-08 15:14:09     10  2077116639  1976832558889756
# 4      2021-09-08 15:14:09     11  2077116639  1976832558889756
# ...                    ...    ...         ...               ...
# 58897  2021-09-09 18:42:47  64413  2129636999  8674739858022974
# 58898  2021-09-09 18:42:47  64414  2129636999  8674739858022974
# 58899  2021-09-09 18:42:47  64415  2129636999  8674739858022974
# 58900  2021-09-09 18:42:47  64416  2129636999  8674739858022974
# 58901  2021-09-09 18:42:47  64417  2129636999  8674739858022974
#
#                      extension_session_uuid  event_ordinal       record_type  \
# 0      4392dfdf-9435-410b-8895-ad4edc591fda            191  added-or-changed
# 1      4392dfdf-9435-410b-8895-ad4edc591fda            192  added-or-changed
# 2      4392dfdf-9435-410b-8895-ad4edc591fda            259  added-or-changed
# 3      4392dfdf-9435-410b-8895-ad4edc591fda            343  added-or-changed
# 4      4392dfdf-9435-410b-8895-ad4edc591fda            344  added-or-changed
# ...                                     ...            ...               ...
# 58897  4b7cdd00-2584-42f5-b3c7-ce3b6d03081e           1867  added-or-changed
# 58898  4b7cdd00-2584-42f5-b3c7-ce3b6d03081e           2025           deleted
# 58899  4b7cdd00-2584-42f5-b3c7-ce3b6d03081e           2026  added-or-changed
# 58900  4b7cdd00-2584-42f5-b3c7-ce3b6d03081e           2027           deleted
# 58901  4b7cdd00-2584-42f5-b3c7-ce3b6d03081e           2028  added-or-changed
#
#       change_cause  ...       same_site         store_id  \
# 0         explicit  ...  no_restriction  firefox-default
# 1         explicit  ...  no_restriction  firefox-default
# 2         explicit  ...  no_restriction  firefox-default
# 3         explicit  ...  no_restriction  firefox-default
# 4         explicit  ...  no_restriction  firefox-default
# ...            ...  ...             ...              ...
# 58897     explicit  ...  no_restriction  firefox-default
# 58898    overwrite  ...  no_restriction  firefox-default
# 58899     explicit  ...  no_restriction  firefox-default
# 58900    overwrite  ...  no_restriction  firefox-default
# 58901     explicit  ...  no_restriction  firefox-default
#
#                      time_stamp               crawl is_third_party  \
# 0      2021-09-08T15:13:32.032Z     pilot_1_US_base    first_party
# 1      2021-09-08T15:13:32.033Z     pilot_1_US_base    first_party
# 2      2021-09-08T15:13:32.643Z     pilot_1_US_base    third_party
# 3      2021-09-08T15:13:34.343Z     pilot_1_US_base    third_party
# 4      2021-09-08T15:13:34.344Z     pilot_1_US_base    third_party
# ...                         ...                 ...            ...
# 58897  2021-09-09T18:42:44.183Z  pilot_1_US_misinfo    third_party
# 58898  2021-09-09T18:42:49.202Z  pilot_1_US_misinfo    third_party
# 58899  2021-09-09T18:42:49.204Z  pilot_1_US_misinfo    third_party
# 58900  2021-09-09T18:42:49.204Z  pilot_1_US_misinfo    third_party
# 58901  2021-09-09T18:42:49.205Z  pilot_1_US_misinfo    third_party
#
#              ps_plus_1 top_level_domain disconnect_tracker_category  \
# 0           bavnews.am              .am                         NaN
# 1           bavnews.am              .am                         NaN
# 2      doubleclick.net             .net                  Disconnect
# 3            yandex.ru              .ru                     Content
# 4            yandex.ru              .ru                     Content
# ...                ...              ...                         ...
# 58897  shareaholic.com             .com                      Social
# 58898  shareaholic.com             .com                      Social
# 58899  shareaholic.com             .com                      Social
# 58900  shareaholic.com             .com                      Social
# 58901  shareaholic.com             .com                      Social
#
#          companies is_disconnect_tracker
# 0                0                 False
# 1                0                 False
# 2           Google                  True
# 3           Yandex                  True
# 4           Yandex                  True
# ...            ...                   ...
# 58897  Shareaholic                  True
# 58898  Shareaholic                  True
# 58899  Shareaholic                  True
# 58900  Shareaholic                  True
# 58901  Shareaholic                  True
#
# [58902 rows x 29 columns]
